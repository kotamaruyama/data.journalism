# %%
import pandas as pd
import numpy as np
import matplotlib 
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/saira1920/data_set/master/gapminder.csv')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.columns=['country', 'continent', 'year', 'life_exp', 'pop', 'gdp_per_cap']

# %%
df.head()
# Out:
#        country continent  year  life_exp       pop  gdp_per_cap
# 0  Afghanistan      Asia  1952    28.801   8425333   779.445314
# 1  Afghanistan      Asia  1957    30.332   9240934   820.853030
# 2  Afghanistan      Asia  1962    31.997  10267083   853.100710
# 3  Afghanistan      Asia  1967    34.020  11537966   836.197138
# 4  Afghanistan      Asia  1972    36.088  13079460   739.981106

# %%
df.tail()
# Out:
#        country continent  year  life_exp       pop  gdp_per_cap
# 1699  Zimbabwe    Africa  1987    62.351   9216418   706.157306
# 1700  Zimbabwe    Africa  1992    60.377  10704340   693.420786
# 1701  Zimbabwe    Africa  1997    46.809  11404948   792.449960
# 1702  Zimbabwe    Africa  2002    39.989  11926563   672.038623
# 1703  Zimbabwe    Africa  2007    43.487  12311143   469.709298

# %%
matplotlib.rcParams['font.size']=20
sns.set_context('talk',font_scale=0.9);

# %%
sns.pairplot(df,diag_kind='hist')

# %%
df['log_pop']=np.log10(df['pop'])
df['log_gdp_per_cap']=np.log10(df['gdp_per_cap'])

# %%
df.head()
# Out:
#        country continent  year  life_exp       pop  gdp_per_cap   log_pop  \
# 0  Afghanistan      Asia  1952    28.801   8425333   779.445314  6.925587
# 1  Afghanistan      Asia  1957    30.332   9240934   820.853030  6.965716
# 2  Afghanistan      Asia  1962    31.997  10267083   853.100710  7.011447
# 3  Afghanistan      Asia  1967    34.020  11537966   836.197138  7.062129
# 4  Afghanistan      Asia  1972    36.088  13079460   739.981106  7.116590
#
#    log_gdp_per_cap
# 0         2.891786
# 1         2.914265
# 2         2.931000
# 3         2.922309
# 4         2.869221

# %%
df=df.drop(columns=['pop','gdp_per_cap'])

# %%
sns.pairplot(df,hue='continent',diag_kind='hist')

# %%
matplotlib.rcParams['font.size']=5
sns.set_context('talk',font_scale=1.2);
sns.pairplot(df,hue='continent',diag_kind='kde',
                    plot_kws={'alpha':0.6,'s':80,'edgecolor':'k'},
                     height=4);

# %%
'country', 'continent', 'year', 'life_exp', 'pop', 'gdp_per_cap'
# Out:
# ('country', 'continent', 'year', 'life_exp', 'pop', 'gdp_per_cap')

# %%
sns.pairplot(df[df['year'] >= 2000], 
             vars = ['life_exp', 'log_pop', 'log_gdp_per_cap'],
             hue = 'continent', diag_kind = 'kde',
             plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
             height = 4);
