# %%
# !pip install twint
# Out:
# ...
#      |████████████████████████████████| 1.2MB 6.7MB/s
# ...
#      |████████████████████████████████| 245kB 22.6MB/s
# ...
#      |████████████████████████████████| 225kB 35.1MB/s
# ...
#      |████████████████████████████████| 153kB 34.4MB/s
# ...
#      |████████████████████████████████| 266kB 43.4MB/s
# ...
#      |████████████████████████████████| 81kB 8.2MB/s
# ...
#      |████████████████████████████████| 235kB 37.8MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.20-cp36-none-any.whl size=33922 sha256=e0f02c7096bfaf9e5c580c9254f5ad69370fb660f962bac3d52f80d52fb3b239
#   Stored in directory: /root/.cache/pip/wheels/66/25/c7/855c1d896087ef84df6e6713b8adb073aff99af119450e1e4f
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13485 sha256=744449d3015cb1ad457aff1879c5371a2bcb273b5cf6d467e12dd3d9eba443cc
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# ...

# %%
# !pip install nest_asyncio

# %%
import pandas as pd
import datetime

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()
c.Username = "realDonaldTrump"
c.Store_csv=True
c.Count=True
c.Since='2009-01-01'
c.Until = '2020-08-31'
c.Output='trumptweetnewst'
twint.run.Search(c)
# Out:
# CRITICAL:root:twint.get:User:'NoneType' object is not subscriptable
# 1300195730527784960 2020-08-30 22:16:33 UTC <realDonaldTrump> Rushing him out of basement after seeing some very disturbing numbers. Don’t worry, he’ll go back to basement soon! https://twitter.com/daveweigel/status/1300171791030276097 …
# 1300193398477946883 2020-08-30 22:07:17 UTC <realDonaldTrump> Rest In Peace Jay! https://twitter.com/AmyKremer/status/1300184590028541957 …
# 1300193033581928448 2020-08-30 22:05:50 UTC <realDonaldTrump> A weak and pathetic Democrat Mayor!!! https://twitter.com/BryanDeanWright/status/1300177671020621824 …
# 1300171130326716418 2020-08-30 20:38:48 UTC <realDonaldTrump> The only way you will stop the violence in the high crime Democrat run cities is through strength!
# ...

# %%
df5=pd.read_csv("/root/トランプツイート（サマータイム未反映） - トランプツイート（サマータイム未反映）.csv")

# %%
df5.head()
# Out:
#               datetime  ... likes_count
# 0  2020-08-30 18:16:33  ...     87062.0
# 1  2020-08-30 18:07:17  ...    211074.0
# 2  2020-08-30 18:05:50  ...     67037.0
# 3  2020-08-30 16:38:48  ...    245625.0
# 4  2020-08-30 16:36:36  ...    126496.0
#
# [5 rows x 5 columns]

# %%
df5['datetime']
# Out:
# 0        2020-08-30 18:16:33
# 1        2020-08-30 18:07:17
# 2        2020-08-30 18:05:50
# 3        2020-08-30 16:38:48
# 4        2020-08-30 16:36:36
#                 ...
# 44393    2009-05-12 10:07:28
# 44394    2009-05-08 16:40:15
# 44395     2009-05-08 9:38:08
# 44396    2009-05-04 21:00:10
# 44397    2009-05-04 14:54:25
# Name: datetime, Length: 44398, dtype: object
